# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
import librosa.display
import numpy as np

# Load dataset
df = pd.read_csv("/Users/kantharamoladayam/Documents/heart_disease/data/processed_features.csv")
print(df.head())

# Plot class distribution
plt.figure(figsize=(6, 4))
sns.countplot(x="label", data=df, palette="coolwarm")
plt.title("Class Distribution (Heart Disease vs No Heart Disease)")
plt.xlabel("Label")
plt.ylabel("Count")
plt.show()

# Visualizing feature correlations
plt.figure(figsize=(12, 8))
sns.heatmap(df.iloc[:, 1:-1].corr(), cmap="coolwarm", annot=False)
plt.title("Feature Correlation Heatmap")
plt.show()
import os

# Example: Visualizing an audio file
audio_file = os.path.abspath('/Users/kantharamoladayam/Documents/heart_disease/data/records/84804_MV.wav')
y, sr = librosa.load(audio_file, sr=4000)
plt.figure(figsize=(10, 4))
librosa.display.waveshow(y, sr=sr)
plt.title("Waveform of a Sample Heart Sound")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.show()

# Extracting sample MFCCs
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
plt.figure(figsize=(10, 6))
librosa.display.specshow(mfccs, sr=sr, x_axis="time", cmap="coolwarm")
plt.colorbar(label="MFCC Coefficients")
plt.title("MFCCs of the Sample Heart Sound")
plt.show()
# Out:
#    patient_id      feat_0      feat_1     feat_2     feat_3     feat_4  \
# 0       50336 -313.959930   71.268509  -4.963071  39.584888   6.783984
# 1       50048 -178.742538   65.596718 -20.771971  43.612278  -3.141477
# 2       68347 -148.412506  121.150658  -1.404537  21.596649 -18.065571
# 3       50619 -245.525406   98.092705  -5.363506  30.750256  10.544678
# 4       84960 -116.325989   33.893536   1.180833  35.511440  -5.133789
#
#       feat_5     feat_6     feat_7    feat_8  ...   feat_23   feat_24  \
# 0  32.048363  -4.803300  15.375183 -0.978018  ...  0.729129  0.704888
# 1  29.089874  -3.187591  17.679182  0.616705  ...  0.685522  0.672179
# 2   9.340646 -12.332324   9.637280 -4.761662  ...  0.707984  0.676290
# 3  32.270004  -5.647713  10.091853 -5.629907  ...  0.634148  0.639410
# 4  14.676330 -11.298407   1.033688 -7.908533  ...  0.702384  0.721621
#
#      feat_25    feat_26    feat_27    feat_28    feat_29    feat_30  \
# ...
